# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('CARIT_allRaw.csv')
df.head()
df.shape
# Out:
# (118404, 31)

# %%
df.columns
# Out:
# Index(['condFile', 'trialNum', 'stim', 'corrAns', 'prepotency', 'ISI',
#        'shapeStartTime', 'shapeEndTime', 'fixStartTime', 'fixEndTime',
#        'nogoCondition', 'resp', 'trialResp.firstKey', 'trialResp.firstRt',
#        'corrRespMsg', 'corrRespCode', 'corrRespTrialType', 'isiPress.keys',
#        'isiPress.rt', 'hitCount', 'missCount', 'falseAlarmCount',
#        'corrRejectCount', 'totalAcc', 'goAcc', 'nogoAcc', 'goFiveBackAvg',
#        'nogoFiveBackAvg', 'totalFiveBackAvg', 'filename', 'sessionID'],
#       dtype='object')

# %%
cols = ['sessionID', 'filename', 'condfile', 'trialNum', 'stim', 'corrAns', 'shapeStartTime', 'shapeEndTime', 'fixStartTime', 'fixEndTime', 'trialResp.firstRt']
df.loc[df['trialResp.firstRt'] < df['shapeStartTime'], cols]  # .iloc[1]['filename']
(df['trialResp.firstRt'] - df['shapeStartTime'] < .2).sum()
# Out:
# 263

# %%
# !open -a "Microsoft Excel" /Users/kastman/Dropbox/ANDL/ProjectAnalyses/HCPD/Behavioral/data/CARIT_HCD0039128_V1_A_run1_wide.csv

# %%
df1 = pd.read_csv("/Users/kastman/Dropbox/ANDL/ProjectAnalyses/HCPD/Behavioral/data/CARIT_HCD0039128_V1_A_run1_wide.csv")

# %%
df1[['shapeStartTime', 'trialResp.firstRt']]
# Out:
#     shapeStartTime  trialResp.firstRt
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4         8.044029           8.593850
# 5        10.142855          10.659818
# 6        15.241740          15.825678
# 7        17.341643                NaN
# 8        18.941636          19.410261
# 9        21.041168          21.575773
# 10       23.141068          23.558992
# 11       24.741243          25.225387
# 12       26.840669          27.342337
# 13       29.940544          30.425987
# 14       33.040162                NaN
# 15       34.640718          35.125021
# 16       37.739725          38.241822
# 17       39.840360                NaN
# 18       42.939298          43.374254
# 19       44.539231          45.040680
# 20       46.639077                NaN
# 21       48.238800          48.773222
# 22       53.337801          53.823186
# 23       56.438124          56.887686
# ...

# %%
# !open -a "Microsoft Excel" /Users/kastman/Dropbox/ANDL/ProjectAnalyses/HCPD/Behavioral/data/CARIT_HCD1268350_V1_A_run2_wide.csv
